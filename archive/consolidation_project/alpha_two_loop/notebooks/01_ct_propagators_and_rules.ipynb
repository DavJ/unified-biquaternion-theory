# %% [markdown]
# # CT Propagators and Feynman Rules
#
# This notebook defines the Complex-Time propagators and vertex rules, and checks Ward identities at 1-loop.

# %% [markdown]
# ## TODO: CT Propagator Definitions
#
# Define photon and fermion propagators in the CT scheme with complex time τ = t + iψ.

# %%
# TODO: Implement CT photon propagator
# D_μν(k, ξ) with gauge parameter ξ in CT scheme

# %%
# TODO: Implement CT fermion propagator
# S(p) in CT scheme

# %% [markdown]
# ## TODO: Vertex Rules
#
# Define the photon-fermion vertex in the CT scheme.

# %%
# TODO: Implement CT vertex rule
# ieγ^μ with appropriate CT modifications

# %% [markdown]
# ## TODO: 1-Loop Ward Identity Checks
#
# Verify that Z_1 = Z_2 at 1-loop order.

# %%
# TODO: Compute 1-loop vertex correction Z_1
# TODO: Compute 1-loop fermion wavefunction Z_2
# TODO: Verify Z_1 = Z_2 for various gauge parameters ξ

# %% [markdown]
# ## Expected Cancellations
#
# - Gauge parameter ξ should cancel in physical observables
# - Ward identity Z_1 = Z_2 must hold

# %% [markdown]
# ## QED/Real-Time Limit Checks
#
# Verify that in the limit ψ → 0, all results reduce to standard QED.

# %%
# TODO: Check ψ → 0 limit recovers QED propagators
# TODO: Check ψ → 0 limit recovers QED vertex
# TODO: Check ψ → 0 limit gives Z_1 = Z_2 = QED values
